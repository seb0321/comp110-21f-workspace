# %% [markdown]
# ## Hypothesis: I think most people in this course do not have the intention to major in CS.

# %% [markdown]
# PID:

# %%
__author__ = "730358517"

# %% [markdown]
# First I am going to enable autoreload of imported modules.

# %%
# %reload_ext autoreload
# %autoreload 2

# %% [markdown]
# I will then use the find the directory for the data we need.

# %%
DATA_DIRECTORY="/Users/sarahbarnes/comp110-exercises/comp110-21f-workspace/data"
DATA_FILE_PATH=f"{DATA_DIRECTORY}/survey.csv"

# %% [markdown]
# First I will read the csv and convert it to a column-oritented data table.

# %%
from data_utils import columnar, read_csv_rows

data_rows: list[dict[str, str]] = read_csv_rows('../../data/survey.csv')
columns: dict[str, list[str]] = columnar(data_rows)

# %% [markdown]
# Next, I will select the comp_major column. Here are the first twenty-five rows to give us an idea of what the data says...

# %%
from data_utils import head, select
subset: dict[str, list[str]] = select(columns, ["comp_major"])
head(subset, 25)
# Out:
# {'comp_major': ['No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'Yes - Minor',
#   'No']}

# %% [markdown]
# Now I will count up the totals of each.

# %%
from data_utils import count
counts = count(subset['comp_major'])
print(f"Total intention to major in CS: {counts['Yes - BA'] + counts['Yes - BS'] + counts['Yes - Minor']} ")
print(f"Total no intention to major in CS: {counts['No']} ")
print(f"Total responses: {counts['Yes - BA'] + counts['Yes - BS'] + counts['Yes - Minor'] + counts['No']} ")
# Out:
# Total intention to major in CS: 169
# Total no intention to major in CS: 404
# Total responses: 573

# %% [markdown]
# I will then use my helper function to calculate what percent of students intend to major in CS and what percent of students do not intend to major in CS.

# %%
from data_utils import percentage
print(f"Percent of people that intend on majoring in CS: {percentage(169, 573)} ")
print(f"Percent of people that do not intend on majoring in CS: {percentage(404, 573)} ")
# Out:
# Percent of people that intend on majoring in CS: 29.49389179755672 %
# Percent of people that do not intend on majoring in CS: 70.50610820244329 %

# %% [markdown]
# Two visuals of my data!

# %%
import seaborn

# %%
plot = seaborn.barplot(x=["Yes - BA", "Yes - BS", "Yes - Minor", "No"], y=[counts["Yes - BA"], counts["Yes - BS"], counts["Yes - Minor"], counts["No"]])
plot.set_title('Do students in Comp 110 that intend on majoring in CS?')
plot.set_ylabel('Number of Responses')
plot.set_xlabel('Responses')
# Out:
# Text(0.5, 0, 'Responses')

# %% [markdown]
# This graphs gives a visual comparing all the possible intentions of people to major in computer science. As you can see no has a significantly higher number of responses.

# %%
plot = seaborn.barplot(x=["Yes", "No"], y=[counts['Yes - BA'] + counts['Yes - BS'] + counts['Yes - Minor'], counts["No"]])
plot.set_ylabel('Number of Responses')
plot.set_xlabel('Responses')
plot.set_title('Yes vs. No: students in Comp 110 that intend on majoring in CS?')
# Out:
# Text(0.5, 1.0, 'Yes vs. No: students in Comp 110 that intend on majoring in CS?')

# %% [markdown]
# This graph shows a visual of all Yes answers together versus no. Students who don't intend to major in computer science is still much higher than those who do.

# %% [markdown]
# ## Conclusion

# %% [markdown]
# In conclusion, there were more students taking this class that do not have the intention of majoring in CS. I believe this is because many majors require this class even if you are not a computer science major.
